# %%
from models import ShoppingCart

tobe = ShoppingCart.objects.all()

print(tobe)
# Out:
# ---------------------------------------------------------------------------
# ImproperlyConfigured                      Traceback (most recent call last)
# <ipython-input-2-576d13b32948> in <module>
# ----> 1 from models import ShoppingCart
#       2
#       3 tobe = ShoppingCart.objects.all()
#       4
#       5 print(tobe)
#
# ~/Documents/tensorflow_object_counting_api-master/fridge/models.py in <module>
#       1 from django.db import models
# ----> 2 from django.contrib.auth.models import User
#       3 from django.urls import reverse
#       4 # Create your models here.
#       5 import csv
#
# ~/Documents/smarthomeobject/venv/lib/python3.6/site-packages/django/contrib/auth/models.py in <module>
#       2
#       3 from django.contrib import auth
# ----> 4 from django.contrib.auth.base_user import AbstractBaseUser, BaseUserManager
#       5 from django.contrib.auth.signals import user_logged_in
#       6 from django.contrib.contenttypes.models import ContentType
#
# ...
